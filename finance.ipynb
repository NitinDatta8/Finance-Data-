# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style('darkgrid')

# %%
df = pd.read_csv(r"C:\Users\movva\Downloads\df.csv")

# %%
df.head()
# Out:
#              Timestamp                NAME  GENDER       AGE  \
# 0  06/03/2020 05:26:19          Rekha Jain  Female  ABOVE 32
# 1  06/03/2020 06:02:53       Hamsa Rajaram  Female     20-24
# 2  06/03/2020 07:50:19          vikas jain    Male     28-32
# 3  06/03/2020 08:26:01  Nadeem Fouzan Khan    Male     20-24
# 4  06/03/2020 20:12:54               Hemal  Female     20-24
#
#   Do you invest in Investment Avenues?  \
# 0                                  Yes
# 1                                  Yes
# 2                                  Yes
# 3                                  Yes
# 4                                   No
#
#    What do you think are the best options for investing your money? (Rank in order of preference) [Mutual Funds]  \
# 0                                                  1
# 1                                                  4
# 2                                                  3
# 3                                                  2
# ...

# %%
df.drop(['Timestamp','NAME','Do you invest in tax saving instruments?'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['GENDER', 'AGE', 'Do you invest in Investment Avenues?',
#        'What do you think are the best options for investing your money? (Rank in order of preference) [Mutual Funds]',
#        'What do you think are the best options for investing your money? (Rank in order of preference) [Equity Market]',
#        'What do you think are the best options for investing your money? (Rank in order of preference) [Debentures]',
#        'What do you think are the best options for investing your money? (Rank in order of preference) [Government Bonds]',
#        'What do you think are the best options for investing your money? (Rank in order of preference) [Fixed Deposits]',
#        'What do you think are the best options for investing your money? (Rank in order of preference) [Public Provident Fund]',
#        'What do you think are the best options for investing your money? (Rank in order of preference) [Gold]',
#        'Do you invest in Stock Market?',
# ...

# %%
df=df.rename(columns={"GENDER": "gender", "AGE": "age","Do you invest in Investment Avenues?": "Investment_Avenues",
                   "What do you think are the best options for investing your money? (Rank in order of preference) [Mutual Funds]": "Mutual_Funds",
                   'What do you think are the best options for investing your money? (Rank in order of preference) [Equity Market]': "Equity_Market",
                   'What do you think are the best options for investing your money? (Rank in order of preference) [Debentures]': "Debentures",
                   'What do you think are the best options for investing your money? (Rank in order of preference) [Government Bonds]': "Government_Bonds",
                   'What do you think are the best options for investing your money? (Rank in order of preference) [Fixed Deposits]': "Fixed_Deposits",
                   'What do you think are the best options for investing your money? (Rank in order of preference) [Public Provident Fund]': "PPF",
                   'What do you think are the best options for investing your money? (Rank in order of preference) [Gold]': "Gold",
                   'Do you invest in Stock Market?': "Stock_Marktet",
                   'What are the factors considered by you while investing in any instrument?': "Factor",
                   "What is your investment objective?": "Objective",
                   'What is your purpose behind investment?': "Purpose",
                   'How long do you prefer to keep your money in any investment instrument?': "Duration"
                   ,'How often do you monitor your investment?': "Invest_Monitor",
                   'How much return do you expect from any investment instrument?': "Expect",
                  'Which investment avenue do you mostly invest in?':"Avenue",
                   'Reasons for investing in Equity Market':"Reason_Equity",
                   'Reasons for investing in Mutual Funds':"Reason_Mutual",
                   'Reasons for investing in Government Bonds':"Reason_Bonds"
                   ,'Reasons for investing in Fixed Deposits ':'Reason_FD',
                   'Your sources of information for investments is ':"Source"
                  })

# %%
df.head()
# Out:
#    gender       age Investment_Avenues  Mutual_Funds  Equity_Market  \
# 0  Female  ABOVE 32                Yes             1              2
# 1  Female     20-24                Yes             4              3
# 2    Male     28-32                Yes             3              6
# 3    Male     20-24                Yes             2              1
# 4  Female     20-24                 No             2              1
#
#    Debentures  Government_Bonds  Fixed_Deposits  PPF  Gold  ...  \
# 0           5                 3               7    6     4  ...
# 1           2                 1               5    6     7  ...
# 2           4                 2               5    1     7  ...
# 3           3                 7               6    4     5  ...
# 4           3                 6               4    5     7  ...
#
#             Duration Invest_Monitor   Expect       Avenue  \
# 0          1-3 years        Monthly  20%-30%  Mutual Fund
# ...

# %%
df.columns
# Out:
# Index(['gender', 'age', 'Investment_Avenues', 'Mutual_Funds', 'Equity_Market',
#        'Debentures', 'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold',
#        'Stock_Marktet', 'Factor', 'Objective', 'Purpose', 'Duration',
#        'Invest_Monitor', 'Expect', 'Avenue',
#        'What are your savings objectives?', 'Reason_Equity', 'Reason_Mutual',
#        'Reason_Bonds', 'Reason_FD', 'Source'],
#       dtype='object')

# %%
df.drop(['Mutual_Funds', 'Equity_Market',
       'Debentures', 'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    gender       age Investment_Avenues Stock_Marktet          Factor  \
# 0  Female  ABOVE 32                Yes           Yes         Returns
# 1  Female     20-24                Yes            No  Locking Period
# 2    Male     28-32                Yes           Yes         Returns
# 3    Male     20-24                Yes           Yes         Returns
# 4  Female     20-24                 No            No         Returns
#
#               Objective          Purpose           Duration Invest_Monitor  \
# 0  Capital Appreciation  Wealth Creation          1-3 years        Monthly
# 1  Capital Appreciation  Wealth Creation  More than 5 years         Weekly
# 2  Capital Appreciation  Wealth Creation          3-5 years          Daily
# 3                Income  Wealth Creation   Less than 1 year          Daily
# 4                Income  Wealth Creation   Less than 1 year          Daily
#
#     Expect       Avenue What are your savings objectives?  \
# ...

# %%
# First we will see Gender of our respondenets
sns.countplot(df['gender'])

# %%
# Now we will see Age of our respondents
sns.countplot(df['age'])


'''We can see from the below graph that most of our respondents were in the ages 24-32 and we will look further
their habits in the finanace field '''

# %%
sns.countplot(x=df['age'],hue=df['gender'],palette='spring')

# From the below plot we can see that most of the males were between 24-32

# %%
# Now lets see age wise  whether people invest in INVESTMENT AVENUES and STOCK MARKET 
plt.figure(figsize=(18,6))
plt.subplot(1, 2, 1)
sns.countplot(x=df['age'],hue=df['Investment_Avenues'],palette='summer')
plt.title('INVESTMENT AVENUE')
plt.subplot(1, 2, 2)
sns.countplot(x=df['age'],hue=df['Stock_Marktet'],palette='hot')
plt.title('STOCK MARKET')
plt.show()


# Only 3 people dont invest and 5 people dont go to stock market

# %%
# Now lets see these same factors of INVESTMENT_AVENUE and STOCK_MARKET with gender

plt.figure(figsize=(18,6))
plt.subplot(1, 2, 1)
sns.countplot(x=df['gender'],hue=df['Investment_Avenues'],palette='summer')
plt.title('INVESTMENT AVENUE')
plt.subplot(1, 2, 2)
sns.countplot(x=df['gender'],hue=df['Stock_Marktet'],palette='hot')
plt.title('STOCK MARKET')
plt.show()


# Mostly females dont invest or go to stocks

# %%
# Factors affecting Investing 
sns.countplot(x=df['Factor'],palette='coolwarm')

# Returns is the most influential Factor considered while investing which is followed by risk

# %% [markdown]
# ## The above trend shows us that people are less worried about risks involved and more worried about the money which they will get back

# %%
# Lets see which Age groups take the highest risk 
plt.figure(figsize=(18,6))
plt.subplot(1, 2, 1)
sns.countplot(x=df['age'],hue=df['Factor'],palette='magma')
plt.title('Age')
plt.subplot(1, 2, 2)
sns.countplot(x=df['gender'],hue=df['Factor'],palette='Oranges')
plt.title('Gender')
plt.show()

# %% [markdown]
# ### We can see that 24-32 aged people try to focus more on returns than the risks involved, which might be because they want to earn more and more also high number of males are dependent on Returns
